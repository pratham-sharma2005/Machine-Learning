# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer

# %%
df=pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/refs/heads/main/day31-power-transformer/concrete_data.csv")

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
# no values are negative but we do have min count as zero

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.drop("Strength",axis=1),df["Strength"],test_size=0.2,random_state=42)

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
Y_pred=lr.predict(X_test)
r2_score(Y_test,Y_pred)
# Out:
# 0.627553179231485

# %%
#Plotting all the plots

# %%
sns.distplot(df["Cement"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/4084184316.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cement"])
# <Axes: xlabel='Cement', ylabel='Density'>

# %%
stats.probplot(df["Cement"],dist="norm",plot=plt)
plt.show()

# %%
# above graph is so so mostly on the red line

# %%
sns.distplot(df["Blast Furnace Slag"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/2744612987.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Blast Furnace Slag"])
# <Axes: xlabel='Blast Furnace Slag', ylabel='Density'>

# %%
stats.probplot(df["Blast Furnace Slag"],dist="norm",plot=plt)
plt.show()

# %%
#Above graph is right skewd

# %%
sns.distplot(df["Fly Ash"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/3063006634.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fly Ash"])
# <Axes: xlabel='Fly Ash', ylabel='Density'>

# %%
stats.probplot(df["Fly Ash"],dist="norm",plot=plt)
plt.show()

# %%
# Aboove graph is bi-model

# %%
sns.distplot(df["Water"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/2728170514.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Water"])
# <Axes: xlabel='Water', ylabel='Density'>

# %%
stats.probplot(df["Water"],dist="norm",plot=plt)
plt.show()

# %%
#Water is also so so

# %%
sns.distplot(df["Superplasticizer"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/3266641650.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Superplasticizer"])
# <Axes: xlabel='Superplasticizer', ylabel='Density'>

# %%
stats.probplot(df["Superplasticizer"],dist="norm",plot=plt)
plt.show()

# %%
#Risht skewd bi-model

# %%
sns.distplot(df["Age"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
stats.probplot(df["Age"],dist="norm",plot=plt)
plt.show()

# %%
#Column with worst Condition

# %%
#APPLYING BOX-COX TRANSFORM

# %%
pt=PowerTransformer(method="box-cox")

X_train_transformed=pt.fit_transform(X_train+0.000001)
X_test_transformed=pt.fit_transform(X_test+0.000001)

pd.DataFrame({"cols":X_train.columns,"box-cox_lambdas":pt.lambdas_})
# Out:
#                  cols  box-cox_lambdas
# 0              Cement         0.215602
# 1  Blast Furnace Slag         0.025996
# 2             Fly Ash        -0.006544
# 3               Water         0.959062
# 4    Superplasticizer         0.103365
# 5    Coarse Aggregate         1.192492
# 6      Fine Aggregate         1.973781
# 7                 Age        -0.014692

# %%
#Aplying Linear Regression on Transformed Data

lr=LinearRegression()
lr.fit(X_train_transformed,Y_train)
Y_pred2=lr.predict(X_test_transformed)
r2_score(Y_test,Y_pred2)
# Out:
# 0.8055321002033324

# %%
# Using cross val score

pt = PowerTransformer(method='box-cox')
X_transformed = pt.fit_transform(X_train+0.0000001)

lr = LinearRegression()
np.mean(cross_val_score(lr,X_transformed,Y_train,scoring='r2'))
# Out:
# np.float64(0.7922924858493123)

# %%
# Before and after comparision for Box-Cox Plot
X_train_transformed = pd.DataFrame(X_train_transformed,columns=X_train.columns)

for col in X_train_transformed.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    sns.distplot(X_train_transformed[col])
    plt.title(col)

    plt.show()
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/2848504358.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/2848504358.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Apply Yeo-Johnson transform

pt1 = PowerTransformer()

X_train_transformed2 = pt1.fit_transform(X_train)
X_test_transformed2 = pt1.transform(X_test)

lr = LinearRegression()
lr.fit(X_train_transformed2,Y_train)

y_pred3 = lr.predict(X_test_transformed2)

print(r2_score(Y_test,y_pred3))

pd.DataFrame({'cols':X_train.columns,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
# 0.8161906513339305
#                  cols  Yeo_Johnson_lambdas
# 0              Cement             0.174348
# 1  Blast Furnace Slag             0.015715
# 2             Fly Ash            -0.161447
# 3               Water             0.771307
# 4    Superplasticizer             0.253935
# 5    Coarse Aggregate             1.130050
# 6      Fine Aggregate             1.783100
# 7                 Age             0.019885

# %%
# applying cross val score

pt = PowerTransformer()
X_transformed2 = pt.fit_transform(X_train)

lr = LinearRegression()
np.mean(cross_val_score(lr,X_transformed2,Y_train,scoring='r2'))
# Out:
# np.float64(0.7941782182448474)

# %%
X_train_transformed2 = pd.DataFrame(X_train_transformed2,columns=X_train.columns)

# %%
# Before and after comparision for Yeo-Johnson

for col in X_train_transformed2.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    sns.distplot(X_train_transformed2[col])
    plt.title(col)

    plt.show()
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/1516575210.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_42818/1516575210.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Side by side Lambdas
pd.DataFrame({'cols':X_train.columns,'box_cox_lambdas':pt.lambdas_,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
#                  cols  box_cox_lambdas  Yeo_Johnson_lambdas
# 0              Cement         0.174348             0.174348
# 1  Blast Furnace Slag         0.015715             0.015715
# 2             Fly Ash        -0.161447            -0.161447
# 3               Water         0.771307             0.771307
# 4    Superplasticizer         0.253935             0.253935
# 5    Coarse Aggregate         1.130050             1.130050
# 6      Fine Aggregate         1.783100             1.783100
# 7                 Age         0.019885             0.019885
