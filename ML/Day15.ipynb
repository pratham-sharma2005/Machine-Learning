# %%
#STUDY OF CSV FILES

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df1=df.head()
df1
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",sep=",")
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df = pd.read_csv(
    "/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",
    names=[
        "GENDER*", "AGE#", "SMOKING", "YELLOW_FINGERS", "ANXIETY", "PEER_PRESSURE",
        "CHRONIC DISEASE", "FATIGUE", "ALLERGY", "WHEEZING", "ALCOHOL", "CONSUMING",
        "COUGHING", "SHORTNESS OF BREATH", "SWALLOWING DIFFICULTY", "CHEST PAIN", "LUNG_CANCER"
    ]
)
df
# Out:
#     GENDER* AGE#  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE
# 1         M   69        1               2        2              1
# 2         M   74        2               1        1              1
# 3         F   59        1               1        1              2
# 4         M   63        2               2        2              1
# ..      ...  ...      ...             ...      ...            ...
# 305       F   56        1               1        1              2
# 306       M   70        2               1        1              1
# 307       M   58        2               1        1              1
# 308       M   67        2               1        2              1
# 309       M   62        1               1        1              2
#
#      CHRONIC DISEASE   FATIGUE   ALLERGY  WHEEZING            ALCOHOL  \
# 0    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",index_col="GENDER")
df
# Out:
#         AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# GENDER
# M        69        1               2        2              1                1
# M        74        2               1        1              1                2
# F        59        1               1        1              2                1
# M        63        2               2        2              1                1
# F        63        1               2        1              1                1
# ...     ...      ...             ...      ...            ...              ...
# F        56        1               1        1              2                2
# M        70        2               1        1              1                1
# M        58        2               1        1              1                1
# M        67        2               1        2              1                1
# M        62        1               1        1              2                1
#
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",header=1)
df
# Out:
#      M  69  1  2  2.1  1.1  1.2  2.2  1.3  2.3  2.4  2.5  2.6  2.7  2.8  YES
# 0    M  74  2  1    1    1    2    2    2    1    1    1    2    2    2  YES
# 1    F  59  1  1    1    2    1    2    1    2    1    2    2    1    2   NO
# 2    M  63  2  2    2    1    1    1    1    1    2    1    1    2    2   NO
# 3    F  63  1  2    1    1    1    1    1    2    1    2    2    1    1   NO
# 4    F  75  1  2    1    1    2    2    2    2    1    2    2    1    1  YES
# ..  ..  .. .. ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 303  F  56  1  1    1    2    2    2    1    1    2    2    2    2    1  YES
# 304  M  70  2  1    1    1    1    2    2    2    2    2    2    1    2  YES
# 305  M  58  2  1    1    1    1    1    2    2    2    2    1    1    2  YES
# 306  M  67  2  1    2    1    1    2    2    1    2    2    2    1    2  YES
# 307  M  62  1  1    1    2    1    2    2    2    2    1    1    2    1  YES
#
# [308 rows x 16 columns]

# %%
df = pd.read_csv(
    "/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",
    names=[
        "GENDER*", "AGE#", "SMOKING", "YELLOW_FINGERS", "ANXIETY", "PEER_PRESSURE",
        "CHRONIC DISEASE", "FATIGUE", "ALLERGY", "WHEEZING", "ALCOHOL", "CONSUMING",
        "COUGHING", "SHORTNESS OF BREATH", "SWALLOWING DIFFICULTY", "CHEST PAIN", "LUNG_CANCER"
    ]
)
df
# Out:
#     GENDER* AGE#  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE
# 1         M   69        1               2        2              1
# 2         M   74        2               1        1              1
# 3         F   59        1               1        1              2
# 4         M   63        2               2        2              1
# ..      ...  ...      ...             ...      ...            ...
# 305       F   56        1               1        1              2
# 306       M   70        2               1        1              1
# 307       M   58        2               1        1              1
# 308       M   67        2               1        2              1
# 309       M   62        1               1        1              2
#
#      CHRONIC DISEASE   FATIGUE   ALLERGY  WHEEZING            ALCOHOL  \
# 0    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",usecols=["GENDER","AGE","SMOKING"])
df
# Out:
#     GENDER  AGE  SMOKING
# 0        M   69        1
# 1        M   74        2
# 2        F   59        1
# 3        M   63        2
# 4        F   63        1
# ..     ...  ...      ...
# 304      F   56        1
# 305      M   70        2
# 306      M   58        2
# 307      M   67        2
# 308      M   62        1
#
# [309 rows x 3 columns]

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",skiprows=[1,2])
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        F   59        1               1        1              2
# 1        M   63        2               2        2              1
# 2        F   63        1               2        1              1
# 3        F   75        1               2        1              1
# 4        M   52        2               1        1              1
# ..     ...  ...      ...             ...      ...            ...
# 302      F   56        1               1        1              2
# 303      M   70        2               1        1              1
# 304      M   58        2               1        1              1
# 305      M   67        2               1        2              1
# 306      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  1
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",nrows=100)
df
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       M   69        1               2        2              1
# 1       M   74        2               1        1              1
# 2       F   59        1               1        1              2
# 3       M   63        2               2        2              1
# 4       F   63        1               2        1              1
# ..    ...  ...      ...             ...      ...            ...
# 95      M   60        1               2        2              2
# 96      F   61        2               2        2              1
# 97      M   59        2               1        1              2
# 98      M   64        1               2        2              2
# 99      M   56        2               1        1              1
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                 1         2         1         2                  2
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",encoding="latin-1")
df
#if showing UniCodeDecodeError it means coding is not up8 the original one u need to edit it like we did for Latin-1
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv", on_bad_lines='skip')
df
#used to remove bad lines like all the data has 6 elements in a row and a few bad lines have more or less so they are removed
#Parser error
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",dtype={"AGE":str})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    object
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",parse_dates=["SMOKING"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    object
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df = pd.read_csv("/Users/prathamsharma/Desktop/ML/survey lung cancer.csv",na_values=["M"])
df.dropna(inplace=True)
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2        F   59        1               1        1              2
# 4        F   63        1               2        1              1
# 5        F   75        1               2        1              1
# 7        F   51        2               2        2              2
# 8        F   68        2               1        2              1
# ..     ...  ...      ...             ...      ...            ...
# 295      F   54        2               2        2              1
# 297      F   47        2               2        1              2
# 300      F   63        2               2        2              2
# 302      F   65        2               2        2              2
# 304      F   56        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 2                  1         2         1         2                  1
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 904 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 18.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 347 kB 27.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 11.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv("/Users/prathamsharma/Downloads/Needed/placement.csv")
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
