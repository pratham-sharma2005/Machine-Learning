# %%
# EDA USING BIIVARIATE ANALYSIS

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
tips=pd.read_csv("/Users/prathamsharma/Desktop/ML/tips.csv")
titanic=pd.read_csv("/Users/prathamsharma/Desktop/ML/train_Titanic.csv")
flights=pd.read_csv("/Users/prathamsharma/Desktop/ML/flights.csv")
iris=pd.read_csv("/Users/prathamsharma/Desktop/ML/iris.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["sex"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["sex"],style=tips["smoker"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["sex"],style=tips["smoker"],size=tips["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=titanic["Pclass"],y=titanic["Age"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=titanic["Pclass"],y=titanic["Fare"],hue=titanic["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=titanic["Pclass"],y=titanic["Age"],hue=titanic["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x=titanic["Sex"],y=titanic["Age"],hue=titanic["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(titanic["Age"])
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_20357/2039306196.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Probability of people Dying
sns.distplot(titanic [titanic['Survived']==0] ['Age'], hist=False)
#Probability of people Surviving
sns.distplot(titanic[titanic['Survived']==1]['Age'], hist=False)
# Out:
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_20357/686932276.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic [titanic['Survived']==0] ['Age'], hist=False)
# /var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/ipykernel_20357/686932276.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==1]['Age'], hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
pd.crosstab(titanic["Pclass"],titanic["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic["Pclass"],titanic["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
titanic.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
pd.crosstab(titanic["SibSp"],titanic["Survived"])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /opt/miniconda3/lib/python3.13/site-packages (from scipy) (2.2.6)
# Downloading scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 15.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
tips=pd.read_csv("/Users/prathamsharma/Desktop/ML/tips.csv")
titanic=pd.read_csv("/Users/prathamsharma/Desktop/ML/train_Titanic.csv")
flights=pd.read_csv("/Users/prathamsharma/Desktop/ML/flights.csv")
iris=pd.read_csv("/Users/prathamsharma/Desktop/ML/iris.csv")
sns.clustermap(pd.crosstab(titanic["SibSp"],titanic["Survived"]))

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(iris,)
#gives scatter plot of all numerical datas automatically with each other

# %%
sns.pairplot(iris,hue="Species")

# %%
flights.groupby("year").sum()

# %%
flights.groupby("year").sum().reset_index()

# %%
sns.lineplot(new["year"],new["passengers"])

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (3.10.3)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (2.10.3)
# Requirement already satisfied: PyYAML>=5.0.0 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in /opt/miniconda3/lib/python3.13/site-packages (from pandas-profiling) (2.2.6)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#           exec(compile('''
#           ~~~~^^^^^^^^^^^^
#           # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ...<31 lines>...
#           exec(compile(setup_py_code, filename, "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ''' % ('/private/var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/pip-install-k7mhr7qq/htmlmin_1c08d3efa8a9400b8663fdae01cf866f/setup.py',), "<pip-setuptools-caller>", "exec"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/pip-install-k7mhr7qq/htmlmin_1c08d3efa8a9400b8663fdae01cf866f/setup.py", line 4, in <module>
#           from htmlmin import __version__
#         File "/private/var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/pip-install-k7mhr7qq/htmlmin_1c08d3efa8a9400b8663fdae01cf866f/htmlmin/__init__.py", line 28, in <module>
#           from .main import minify, Minifier
#         File "/private/var/folders/km/pql1mrbj65jbf346hp94yd3h0000gn/T/pip-install-k7mhr7qq/htmlmin_1c08d3efa8a9400b8663fdae01cf866f/htmlmin/main.py", line 28, in <module>
#           import cgi
#       ModuleNotFoundError: No module named 'cgi'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.
